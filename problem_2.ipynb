# %%
MAX_SECONDS = 10
BIT_COUNTS_TO_TEST = [1, 2, 4, 8, 16]

# %%
from subprocess import call
for bits in BIT_COUNTS_TO_TEST:
    for numberCount in range(0, 10000000000, 100000):
        call(["./problem_1", "args", numberCount, bits])
